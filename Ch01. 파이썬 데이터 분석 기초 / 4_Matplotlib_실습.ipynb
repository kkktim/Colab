# %% [markdown]
# <a href="https://colab.research.google.com/github/kkktim/Colab/blob/master/Ch01.%20%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%20%EA%B8%B0%EC%B4%88%20/%204_Matplotlib_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
날짜 : 2022/04/26
이름 : 강태호
내용 : 파이썬 Matplotlib 실습하기

Matplotlib
 - 다양한 시각화 그래프를 지원하는 파이썬 시각화 라이브러리
 - 데이터 탐색 또는 분석결과를 시각화하기 위해 사용하는 파이썬 라이브러리
"""
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#############################################################
#라인차트
plt.title('line')
plt.plot([1, 3, 4, 9, 10, 17])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#x축
plt.title('line2')
plt.plot([10, 20, 30, 40, 50 ,60], [1, 3, 4, 9, 10, 17])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#스타일
plt.title('line3')
plt.plot([10, 20, 30, 40, 50, 60], [1, 3, 4, 9, 10, 17], 'rs:')
plt.grid(True)
plt.show()

# %%
#멀티 라인차트
values = np.arange(0, 5, 0.2)
print(values)

plt.title('line4')
plt.plot(values, values, 'r--')
plt.plot(values, values ** 2, 'g--')
plt.plot(values, values ** 3, 'b--')
plt.show()
# Out:
# [0.  0.2 0.4 0.6 0.8 1.  1.2 1.4 1.6 1.8 2.  2.2 2.4 2.6 2.8 3.  3.2 3.4
#  3.6 3.8 4.  4.2 4.4 4.6 4.8]

# %%
#연습문제
flights = sns.load_dataset('flights')
flights

x = flights.drop_duplicates('year')['year']
y = flights.groupby(by = 'year')['passengers'].agg('sum')


print('x : ', x)
print('y : ', y)

plt.title('flights')
plt.plot(x, y)
plt.show()
# Out:
# x :  0      1949
# 12     1950
# 24     1951
# 36     1952
# 48     1953
# 60     1954
# 72     1955
# 84     1956
# 96     1957
# 108    1958
# 120    1959
# 132    1960
# Name: year, dtype: int64
# y :  year
# 1949    1520
# 1950    1676
# 1951    2042
# 1952    2364
# 1953    2700
# 1954    2867
# 1955    3408
# 1956    3939
# 1957    4421
# 1958    4572
# 1959    5140
# 1960    5714
# Name: passengers, dtype: int64

# %%
#############################################################
#막대차트
plt.title('bar')
plt.bar(['apple', 'banana', 'orange', 'grape'], [5, 3, 7, 9])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#막대차트 연습문제
titanic = sns.load_dataset('titanic')
titanic

#괄호 하나 리스트 괄호 두개 데이터프레임
# age = titanic[['age']]
age = titanic['age']
# age = titanic.iloc[:, 3]
age

df_age = titanic[['age']]
df_age.loc[(df_age.age >= 0) & (df_age.age < 10), 'gen'] = 0
df_age.loc[(df_age.age >= 10) & (df_age.age < 20), 'gen'] = 10
df_age.loc[(df_age.age >= 20) & (df_age.age < 30), 'gen'] = 20
df_age.loc[(df_age.age >= 30) & (df_age.age < 40), 'gen'] = 30
df_age.loc[(df_age.age >= 40) & (df_age.age < 50), 'gen'] = 40
df_age.loc[(df_age.age >= 50) & (df_age.age < 60), 'gen'] = 50
df_age.loc[(df_age.age >= 60) & (df_age.age < 70), 'gen'] = 60
df_age.loc[(df_age.age >= 70) & (df_age.age < 80), 'gen'] = 70
df_age.loc[(df_age.age >= 80) & (df_age.age < 90), 'gen'] = 80
df_age.loc[(df_age.age >= 90) & (df_age.age < 100), 'gen'] = 90
df_age

df_count = df_age.groupby(by='gen').count()
df_count

plt.title('titanic')
# plt.bar(df_count['gen'], df_count['age'])
plt.show

# %%
#############################################################
#히스토그램
data1 = np.random.rand(1000000)   # 0 ~ 1 사이 실수 1000개
data1.round(5)

plt.title('Histogram')
plt.hist(data1, edgecolor='black')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#표준정규분포 히스토그램
data2 = np.random.randn(100000)   #randn 정규분포를 따르게 랜덤한거 뽑는거

plt.title('Histogram')
plt.hist(data2, edgecolor="black")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#히스토그램 연습문제
titanic = sns.load_dataset('titanic')
titanic

plt.title('titanic')
plt.hist(titanic['age'], edgecolor='black')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#############################################################
#산점도
x = np.random.normal(0, 1, 1000)   #평균0 표준편차1 데이터1000개
y = np.random.normal(0, 1, 1000)   

plt.title('scatter')
plt.scatter(x, y)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#산점도 연습문제
tips = sns.load_dataset('tips')
tips

x = tips['total_bill']
y = tips['tip']

plt.title('Tips')
plt.scatter(x, y)
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from numpy.random.mtrand import rand
#############################################################
#박스상자
data1 = np.random.randint(100, size=5)   #임의의 정수 - randint
data2 = np.random.randint(100, size=5)

print('data1 : ', data1)
print('data2 : ', data2)

plt.title('boxplot')
plt.boxplot([data1, data2])
plt.xticks([1, 2], ['data1', 'data2'])
plt.show
# Out:
# data1 :  [98 27 80 47 51]
# data2 :  [21 95 62 45 22]
# <function matplotlib.pyplot.show>

# %%
#박스상자 연습문제
iris = sns.load_dataset('iris')
iris

dataset1 = iris[iris['species'] == 'setosa']['sepal_length']
dataset2 = iris[iris['species'] == 'versicolor']['sepal_length']
dataset3 = iris[iris['species'] == 'virginica']['sepal_length']

plt.title('iris boxplot')
plt.boxplot([dataset1, dataset2, dataset3], labels=['setosa', 'versicolor', 'virginica'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#3차원 산점도
import plotly.express as px

fig = px.scatter_3d(iris, x='sepal_length', y='sepal_width', z='petal_width', color='species')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
